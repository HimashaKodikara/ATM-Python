# %%
pin=1234
current_balance=10000

def display_balance():
    print("Account balance is : {}".format(current_balance))
    
def cash_withdrow(amount):
    global current_balance
    current_balance-=amount
    display_balance()
def cash_deposit(amount):
    global current_balance
    current_balance+=amount
    display_balance()
def check():
     print("Do you want to do anything more(y/n)")
     do=input()

     if do=="n":
        global flag
        print("Have a nice day")
        flag=False

flag=True

while flag:
    print("Selsct what do you want to do")
    print("Acount balance : press 1")
    print("Acount withdrowal : press 2")  
    print("Acount beposit : press 3")
    
    choice=input()
    
    if choice=="1":
        display_balance()
        check()
       
    elif choice=="2":
        print("Enter the amount you need to withdraw")
        value=float(input("Amount :"))
        cash_withdrow(value)
        check()
    elif choice=="3":
        print("Enter the amount you need to deposit")
        value=float(input("Amount :"))
        cash_deposit(value)
        check()
    else:
        pass
# Out:
# Selsct what do you want to do
# Acount balance : press 1
# Acount withdrowal : press 2
# Acount beposit : press 3
# Selsct what do you want to do
# Acount balance : press 1
# Acount withdrowal : press 2
# Acount beposit : press 3
# Enter the amount you need to deposit
# Account balance is : 10001.0
# Do you want to do anything more(y/n)
# Selsct what do you want to do
# Acount balance : press 1
# Acount withdrowal : press 2
# Acount beposit : press 3
# Selsct what do you want to do
# Acount balance : press 1
# Acount withdrowal : press 2
# Acount beposit : press 3

# %%
card_details={"un":["abc","xyz","pqr"],"pin":[1234,5678,1357],"balance":[10000,50000,20000]}

def display_balance():
    print("Account balance is : {}".format(card_details["balance"][card_details["un"].index(entered_un)]))
    print("*****************************************************************************")

def cash_withdrow(amount):
    card_details["balance"][card_details["un"].index(entered_un)]-=amount
    display_balance()
def cash_deposit(amount):
    card_details["balance"][card_details["un"].index(entered_un)]+=amount
    display_balance()
def check():
     print("Do you want to do anything more(y/n)")
     do=input()

     if do=="n":
        global flag
        print("Have a nice day")
        flag=False

entered_un=input("Please enter your username:")
if entered_un in card_details["un"]:
    entered_pin=int(input("Please enter your card pin number:"))
    count=0
    while entered_pin!=card_details["pin"][card_details["un"].index(entered_un)]:
        if count==5:
            print("You have tried the maximum number of times. Enter your card again and try")
            break
        print("Entered pin is incorrect. You have "+str(5-count)+" more times to try")
        print("**************************************************************************")
        entered_pin=int(input("Check again and enter your correct card pin number:"))
        count=count+1
        
    else:
        print("You have accessed to the machine")
       

     
        flag=True

        while flag:
            print("Selsct what do you want to do")
            print("Acount balance : press 1")
            print("Acount withdrowal : press 2")  
            print("Acount beposit : press 3")

            choice=input()

            if choice=="1":
                display_balance()
                check()

            elif choice=="2":
                print("Enter the amount you need to withdraw")
                value=float(input("Amount :"))
                cash_withdrow(value)
                check()
            elif choice=="3":
                print("Enter the amount you need to deposit")
                value=float(input("Amount :"))
                cash_deposit(value)
                check()
            else:
                pass
            
else:
    print("Entered username is incorrect. You have to enter the card again and enter a valid username")

# %%
import pandas as pd
df=card_details=pd.read_csv("D:\\Python\\atm.CSV")
card_details=df.to_dict("list")

def display_balance():
    print("Account balance is : {}".format(card_details["balance"][card_details["un"].index(entered_un)]))
    print("*****************************************************************************")

def cash_withdrow(amount):
    card_details["balance"][card_details["un"].index(entered_un)]-=amount
    display_balance()
def cash_deposit(amount):
    card_details["balance"][card_details["un"].index(entered_un)]+=amount
    display_balance()
def check():
     print("Do you want to do anything more(y/n)")
     do=input()

     if do=="n":
        global flag
        print("Have a nice day")
        flag=False

entered_un=input("Please enter your username:")
if entered_un in card_details["un"]:
    entered_pin=int(input("Please enter your card pin number:"))
    count=0
    while entered_pin!=card_details["pin"][card_details["un"].index(entered_un)]:
        if count==5:
            print("You have tried the maximum number of times. Enter your card again and try")
            break
        print("Entered pin is incorrect. You have "+str(5-count)+" more times to try")
        print("**************************************************************************")
        entered_pin=int(input("Check again and enter your correct card pin number:"))
        count=count+1
        
    else:
        print("You have accessed to the machine")
       

     
        flag=True

        while flag:
            print("Selsct what do you want to do")
            print("Acount balance : press 1")
            print("Acount withdrowal : press 2")  
            print("Acount beposit : press 3")

            choice=input()

            if choice=="1":
                display_balance()
                check()

            elif choice=="2":
                print("Enter the amount you need to withdraw")
                value=float(input("Amount :"))
                cash_withdrow(value)
                check()
            elif choice=="3":
                print("Enter the amount you need to deposit")
                value=float(input("Amount :"))
                cash_deposit(value)
                check()
            else:
                pass
else:
    print("Entered username is incorrect. You have to enter the card again and enter a valid username")

# %%
df.to_dict("list")
